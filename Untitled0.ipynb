# %% [markdown]
# <a href="https://colab.research.google.com/github/rajaraja2003/data-structure-and-design/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = [[1,2,3],[1,2,2],[1,3,2]]
myvar = pd.DataFrame(data)
myvar
# Out:
#    0  1  2
# 0  1  2  3
# 1  1  2  2
# 2  1  3  2

# %%
calories = {"day1": 420,"day2": 380, "day3": 390}
myvar = pd.series(calories)
myvar
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-f9e0e8cf4ef6> in <cell line: 2>()
#       1 calories = {"day1": 420,"day2": 380, "day3": 390}
# ----> 2 myvar = pd.series(calories)
#       3 myvar
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
calories = {"day1":420, "day2":380, "day3":390}
myvar = pd.series(calories)
myvar
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-ecba78ff6305> in <cell line: 2>()
#       1 calories = {"day1":420, "day2":380, "day3":390}
# ----> 2 myvar = pd.series(calories)
#       3 myvar
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
data = {"na,e":["alice","devin","david",],"age":[25,56,56],
        "city":["delhi","africa","chennai"]}
df = pd.DataFrame(data)
df
# Out:
#     na,e  age     city
# 0  alice   25    delhi
# 1  devin   56   africa
# 2  david   56  chennai
